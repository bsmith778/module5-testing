# %% [markdown]
# # Module 5 Testing Assignment
#
# This notebook documents the steps I completed to write and run a unit test using Python's unittest framework.

# %%
def add(a, b):
    return a + b

# %% [markdown]
# Here is the test file I created in VS Code:
#
# import unittest
# from calculator import add
#
# class TestCalculator(unittest.TestCase):
#     def test_add(self):
#         self.assertEqual(add(2, 3), 5)
#         self.assertEqual(add(-1, 1), 0)
#         self.assertEqual(add(0, 0), 0)
#
# if __name__ == '__main__':
#     unittest.main()

# %% [markdown]
# ### Test Results Explanation
# When I ran `test_calculator.py`, the output showed that 1 test was run and the result was `OK`.
# This means all the assertions in my test passed. In other words, for each set of inputs I used
# (2 and 3, -1 and 1, 0 and 0), the `add` function returned exactly the values I expected.
# Because there were no failures or errors, I can be confident that the `add` function works
# correctly for the cases I tested.
